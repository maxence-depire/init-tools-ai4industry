# %% [markdown]
# # Visualisation de donnée avec `Seaborn`.
#
# La bibliothèque Seaborn permet de

# %% [markdown]
# ## Ouverture du fichier `csv`.

# %%
import pandas as pd
df = pd.read_csv("csv_test.csv")

data = {
    'temps' : df['temps'],
    'température' : df['température']
}

# %% [markdown]
# ## Création d'un `dataset`.

# %%
my_dataset = pd.DataFrame(data)

# %% [markdown]
# ## Création d'un graphique, type `lineplot`.

# %%
sns.set_theme(style="darkgrid")

sns.lineplot(
    data=my_dataset,
    x='temps',
    y='température'
)
# Out:
# <AxesSubplot:xlabel='temps', ylabel='température'>

# %% [markdown]
# ## Autre exemple.

# %%
sns.set_theme(style="darkgrid")

sns.lineplot(
    x="temps",
    y="température",
    hue="température",
    data=my_dataset
)
# Out:
# <AxesSubplot:xlabel='temps', ylabel='température'>
