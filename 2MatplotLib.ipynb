# %% [markdown]
# # Parce que les graphs c'est bien.
#
# Nous allons utiliser la bibliothèques `matplotlib`.

# %% [markdown]
# ## Import de la bibliothèque.
#
# Normalement avec la commande présente dans le `README`, cette bilbiothèque est installé.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Création, et affichage d'un graphique.
#
# `Jupyter` permet de voir les résulats directement dans l'interface. Le graphique va donc apparaitre juste en-dessous.

# %%
# N'oubliez pas d'exécuter d'abord la première cellule pour importer la bibliothèque sinon on aura une erreur.

plt.plot([1, 2, 3, 4], [1, 2, 3, 4])
plt.show()
